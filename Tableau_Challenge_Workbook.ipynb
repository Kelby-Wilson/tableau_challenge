# %%
# Import Dependencies
import pandas as pd
import glob

# %%
# glob.glob('data*.csv') - returns List[str]
# pd.read_csv(f) - returns pd.DataFrame()
# for f in glob.glob() - returns a List[DataFrames]
# pd.concat() - returns one pd.DataFrame()
clean_data_ridership = pd.concat([pd.read_csv(f) for f in glob.glob('data/2019_Jan-Mar_Citi_Bike_Data/*.csv')], ignore_index = True)
clean_data_trip = pd.concat([pd.read_csv(f) for f in glob.glob('data/January_citibike-tripdata/*.csv')], ignore_index = True)
clean_data_trip = pd.concat([pd.read_csv(f) for f in glob.glob('data/February_citibike-tripdata/*.csv')], ignore_index = True)
clean_data_trip = pd.concat([pd.read_csv(f) for f in glob.glob('data/March-citibike-tripdata/*.csv')], ignore_index = True)

# %%
clean_data_ridership.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/19                                              22145
# 1  1/2/19                                              38249
# 2  1/3/19                                              42181
# 3  1/4/19                                              44420
# 4  1/5/19                                              17636
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        44131
# 1                                        58975
# 2                                        62500
# 3                                        65739
# 4                                        24326
#
#    Total Annual Members (All Time)  \
# 0                           297823
# 1                           297908
# 2                           297976
# 3                           298017
# 4                           298048
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
clean_data_ridership.count()
# Out:
# Date                                                  90
# Trips over the past 24-hours (midnight to 11:59pm)    90
# Miles traveled today (midnight to 11:59 pm)           90
# Total Annual Members (All Time)                       90
# 24-Hour Passes Purchased (midnight to 11:59 pm)       90
# 3-Day Passes Purchased (midnight to 11:59 pm)         90
# dtype: int64

# %%
clean_data_trip.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
clean_data_trip.count()
# Out:
# tripduration               18565
# starttime                  18565
# stoptime                   18565
# start station id           18565
# start station name         18565
# start station latitude     18565
# start station longitude    18565
# end station id             18565
# end station name           18565
# end station latitude       18565
# end station longitude      18565
# bikeid                     18565
# usertype                   18565
# birth year                 18565
# gender                     18565
# dtype: int64

# %%
# Export to csv
clean_data_ridership.to_csv("data/clean_quarter_data_2019.csv")
clean_data_trip.to_csv("data/clean_trip_data_2019.csv")
